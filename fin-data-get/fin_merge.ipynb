# %%
import pandas as pd
import numpy as np

# %%
fnlttSingAcntAll_df = pd.read_csv('./fin_data/fnlttSinglAcntAll_2022_raw_data.csv')
fnlttSingAcntAll_df.head()
# Out:
#          rcept_no  reprt_code  bsns_year  corp_code sj_div  sj_nm  \
# 0  20230316000799       11011       2022     173944     BS  재무상태표
# 1  20230316000799       11011       2022     173944     BS  재무상태표
# 2  20230316000799       11011       2022     173944     BS  재무상태표
# 3  20230316000799       11011       2022     173944     BS  재무상태표
# 4  20230316000799       11011       2022     173944     BS  재무상태표
#
#                               account_id account_nm account_detail thstrm_nm  \
# 0                ifrs-full_CurrentAssets       유동자산              -    제 43 기
# 1       ifrs-full_CashAndCashEquivalents   현금및현금성자산              -    제 43 기
# 2          dart_ShortTermTradeReceivable       매출채권              -    제 43 기
# 3            dart_CurrentDerivativeAsset       계약자산              -    제 43 기
# 4  ifrs-full_OtherCurrentFinancialAssets   기타유동금융자산              -    제 43 기
#
#    ...  frmtrm_nm frmtrm_amount  bfefrmtrm_nm bfefrmtrm_amount  ord  currency  \
# ...

# %%
fnlttSingAcntAll_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390078 entries, 0 to 390077
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rcept_no           390078 non-null  int64
#  1   reprt_code         390078 non-null  int64
#  2   bsns_year          390078 non-null  int64
#  3   corp_code          390078 non-null  int64
#  4   sj_div             390078 non-null  object
#  5   sj_nm              390078 non-null  object
#  6   account_id         390078 non-null  object
#  7   account_nm         390078 non-null  object
#  8   account_detail     390078 non-null  object
#  9   thstrm_nm          390078 non-null  object
#  10  thstrm_amount      370423 non-null  float64
#  11  frmtrm_nm          195293 non-null  object
#  12  frmtrm_amount      183181 non-null  float64
#  13  bfefrmtrm_nm       108042 non-null  object
#  14  bfefrmtrm_amount   97130 non-null   float64
# ...

# %%
# fnlttSingAcntAll_df['sj_nm'].unique()
# array(['재무상태표', '포괄손익계산서', '현금흐름표', '자본변동표', '손익계산서'], dtype=object)
sj_nm = '재무상태표'
def sj_nm_list_account_nm(sj_nm):
    reprt_code=11011
    str_expr = "(sj_nm == @sj_nm) and (reprt_code==@reprt_code)"
    list_acc = fnlttSingAcntAll_df.query(str_expr)['account_nm'].unique().tolist()
    print(sj_nm,'의 회계계정명 : ',len(list_acc))
    print()
    for name in list_acc:
        print(name, end=', ')
# fnlttSingAcntAll_df[(fnlttSingAcntAll_df.sj_nm=='현금흐름표') & (fnlttSingAcntAll_df.reprt_code==11011)]['account_nm'].unique().__len__()

# %%
sj_nm_list = ['재무상태표', '포괄손익계산서', '현금흐름표', '자본변동표', '손익계산서']
for sj_nm in sj_nm_list:
    sj_nm_list_account_nm(sj_nm)

# %%
account_nm_uniq = fnlttSingAcntAll_df.loc[fnlttSingAcntAll_df['reprt_code']==11011]['account_nm'].unique()
display(account_nm_uniq.tolist()[-10:])
# Out:
# ['비유동생물자산의 처분',
#  '기타포괄금융자산의 취득',
#  '기타포괄금융자산의 처분',
#  '파생상품계약에 따른 현금유출',
#  '순확정급여의 재측정 요소',
#  '순확정부채의 재측정손익',
#  '위험회피수단으로 지정된 파생상품평가손익',
#  '단기기타금융자산의 처분',
#  '단기기타금융자산의 취득',
#  '순확정부채의 재측정요소']

# %%
fnlttSingAcntAll_df[fnlttSingAcntAll_df['account_nm'].isin(['유동부채','단기차입금','장기차입금'])]
# Out:
#               rcept_no  reprt_code  bsns_year  corp_code sj_div  sj_nm  \
# 19      20200330003191       11011       2019     159412     BS  재무상태표
# 134     20191114001695       11014       2019     159412     BS  재무상태표
# 238     20190814001494       11012       2019     159412     BS  재무상태표
# 343     20190515001740       11013       2019     159412     BS  재무상태표
# 438     20200330002594       11011       2019     173944     BS  재무상태표
# ...                ...         ...        ...        ...    ...    ...
# 389893  20190814000663       11012       2019     422895     BS  재무상태표
# 389898  20190814000663       11012       2019     422895     BS  재무상태표
# 389994  20190515000886       11013       2019     422895     BS  재무상태표
# 389997  20190515000886       11013       2019     422895     BS  재무상태표
# 390002  20190515000886       11013       2019     422895     BS  재무상태표
#
#                           account_id account_nm account_detail    thstrm_nm  \
# ...

# %%
fnlttSingAcntAll_df['account_detail'][-10:]
# Out:
# 390068        자본 [member]|이익잉여금 [member]
# 390069                   별도재무제표 [member]
# 390070                   별도재무제표 [member]
# 390071    자본 [member]|기타포괄손익누계액 [member]
# 390072        자본 [member]|자본잉여금 [member]
# 390073          자본 [member]|자본금 [member]
# 390074        자본 [member]|이익잉여금 [member]
# 390075                  자본 [member]|기타자본
# 390076                   별도재무제표 [member]
# 390077    자본 [member]|기타포괄손익누계액 [member]
# Name: account_detail, dtype: object
